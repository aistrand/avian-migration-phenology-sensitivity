# %%
import matplotlib.pyplot as plt

# %%
# plt.plot([0, 1], [2, 1])
plt.plot(['March', 'April', 'May', 'June'], [2, 1.75, 1.5, 1.25])
plt.xticks(fontsize=15)
plt.yticks([])
plt.xlabel('Median passage date', fontsize=20)
plt.ylabel('Mean body size', fontsize=20)
plt.text(-0.75, 2, 'Larger', fontsize=15)
plt.text(-0.75, 1.25, 'Smaller', fontsize=15)
plt.show()

# %%
plt.plot([-1, 0], [0, 1])
plt.xticks([0, 1], fontsize=15)
plt.yticks([])
plt.xlabel('Δ Timing (days/decade)', fontsize=20)
plt.ylabel('Body mass (g)', fontsize=20)
plt.text(-1.43, 1, 'Larger', fontsize=15)
plt.text(-1.43, 0, 'Smaller', fontsize=15)
plt.text(0.7, -0.12, 'Later', fontsize=15)
plt.text(-1, -0.12, 'Earlier', fontsize=15)
plt.show()

# %%
plt.plot([0, 1], [-1, 0], color='r')
plt.plot([0, 1], [-0.5, 0], color='m')
plt.plot([0, 1], [0, 0], color='b')
plt.xticks([])
plt.yticks([-1 ,0, 1], fontsize=13)
plt.xlabel('Body mass (g)', fontsize=18)
plt.ylabel('Mean arrival date change (days/°C)', fontsize=18)
plt.text(0, -1.29, 'Smaller', fontsize=15)
plt.text(0.85, -1.29, 'Larger', fontsize=15)
plt.text(-0.11, -0.7, 'Earlier', fontsize=15, rotation=90)
plt.text(-0.11, 0.4, 'Later', fontsize=15, rotation=90)
plt.title('MAD change as a function of body mass', fontsize=18)
plt.show()

# %%
plt.plot([0, 1], [-1, 1], color='r')
plt.plot([0, 1], [-0.65, 0.65], color='m')
plt.plot([0, 1], [-0.3, 0.3], color='b')
plt.xticks([])
plt.yticks([-1 ,0, 1], fontsize=15)
plt.xlabel('Body mass (g)', fontsize=18)
plt.ylabel('Mean arrival date shift (days/°C)', fontsize=18)
plt.text(0, -1.29, 'Smaller', fontsize=15)
plt.text(0.85, -1.29, 'Larger', fontsize=15)
plt.text(-0.11, -0.7, 'Earlier', fontsize=15, rotation=90)
plt.text(-0.11, 0.4, 'Later', fontsize=15, rotation=90)
plt.title('MAD shift as a function of body mass', fontsize=18)
plt.show()

# %%
plt.plot([0, 1], [-1, 1])
plt.plot([0, 1], [-0.5, 0.5])
plt.plot([0, 1], [0, 0])
plt.xticks([])
plt.yticks([-1 ,0, 1], fontsize=15)
plt.xlabel('Migration distance (km)', fontsize=18)
plt.ylabel('Mean arrival date shift (days/°C)', fontsize=18)
plt.text(-0.07, -1.29, 'Shorter', fontsize=15)
plt.text(0.91, -1.29, 'Longer', fontsize=15)
plt.text(-0.11, -0.7, 'Earlier', fontsize=15, rotation=90)
plt.text(-0.11, 0.4, 'Later', fontsize=15, rotation=90)
plt.title('MAD shift as a function of migration distance', fontsize=18)
plt.show()

# %%
plt.plot([-1, 0, 1], [1, 0, -1])
plt.plot([-1, 0, 1], [0.75, 0, -0.75])
plt.plot([-1, 0, 1], [0.5, 0, -0.5])
plt.xticks([0], fontsize=15)
plt.yticks([0], fontsize=15)
plt.xlabel('Δ Temperature (°C/decade)', fontsize=20)
plt.ylabel('Δ Timing (days/decade)', fontsize=20)
plt.text(-1.7, 1, 'Later', fontsize=15)
plt.text(-1.7, -1, 'Earlier', fontsize=15)
plt.text(0.65, -1.25, 'Warmer', fontsize=15)
plt.text(-1, -1.25, 'Colder', fontsize=15)
plt.figlegend(('Small-bodied', 'Medium-bodied', 'Large-bodied'), loc=(0.55, 0.62), 
              fontsize=15)
plt.show()

# %%
plt.plot([-1, 0, 1], [1, 0, -1])
plt.plot([-1, 0, 1], [0.75, 0, -0.75])
plt.plot([-1, 0, 1], [0.5, 0, -0.5])
plt.xticks([0], fontsize=15)
plt.yticks([0], fontsize=15)
plt.xlabel('Δ Temperature (°C/decade)', fontsize=20)
plt.ylabel('Δ Timing (days/decade)', fontsize=20)
plt.text(-1.7, 1, 'Later', fontsize=15)
plt.text(-1.7, -1, 'Earlier', fontsize=15)
plt.text(0.65, -1.25, 'Warmer', fontsize=15)
plt.text(-1, -1.25, 'Colder', fontsize=15)
plt.figlegend(('Short-distance', 'Medium-distance', 'Long-distance'), loc=(0.55, 0.62), 
              fontsize=15)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
constant = 10/7

df_routes = pd.DataFrame(np.array([
    [i*constant for i in [0.15, 0.2, 0.2, 0.3, 0.25]], 
    [i*constant for i in [0.15, 0.2, 0.3, 0.3, 0.2]], 
    [i*constant for i in [0.2, 0.3, 0.3, 0.25, 0.25]], 
    [i*constant for i in [0.25, 0.3, 0.3, 0.3, 0.25]], 
    [i*constant for i in [0.15, 0.2, 0.3, 0.3, 0.3]]]))

# %%
ax = sns.heatmap(df_routes, cmap='Reds', vmin=0, vmax=1, xticklabels=False, yticklabels=False)
ax.set_xlabel('Longitude', fontsize=15)
ax.set_ylabel('Latitude', fontsize=15)
ax.set_title(
    'Proportion of occurrence of a given species on a given day in the spring in a given year', fontsize=15)
plt.text(-4, 1, 'A) Birds', fontsize=15)
plt.show()

# %%
constant = 100

df_llj = pd.DataFrame(np.array([
    [i*constant for i in [0.15, 0.23, 0.3, 0.3, 0.25]], 
    [i*constant for i in [0.15, 0.25, 0.3, 0.3, 0.15]], 
    [i*constant for i in [0.25, 0.3, 0.3, 0.25, 0.25]], 
    [i*constant for i in [0.25, 0.3, 0.3, 0.3, 0.25]], 
    [i*constant for i in [0.15, 0.2, 0.3, 0.3, 0.3]]]))

# %%
ax = sns.heatmap(df_llj, cmap='Reds', vmin=0, vmax=70, xticklabels=False, yticklabels=False)
ax.set_xlabel('Longitude', fontsize=15)
ax.set_ylabel('Latitude', fontsize=15)
ax.set_title(
    'Wind speed of the Great Plains low-level jet on a given day in the spring in a given year', fontsize=15)
plt.text(-4, 1, 'B) Great Plains low-level jet', fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([-1, 1], [1, -1])
plt.plot([-1, 1], [0.2, -1])
plt.plot([-1, 1], [-0.5, -0.5])
plt.xticks([-1, 0, 1], fontsize=15)
plt.yticks([0], fontsize=15)
plt.xlabel('Mean arrival date shift (days/°C)', fontsize=18)
plt.ylabel('Population trend (%/year)', fontsize=18)
plt.text(-1.2, 0.3, 'Increase', fontsize=15, rotation=90)
plt.text(-1.22, -0.9, 'Decrease', fontsize=15, rotation=90)
plt.text(0.4, -1.25, 'Later', fontsize=15)
plt.text(-0.6, -1.25, 'Earlier', fontsize=15)
plt.title('Population trend as a function of MAD shift', fontsize=18)
plt.show()
