# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pd.set_option('max_columns', 100)
pd.set_option('max_rows', 100)

# %%
os.getcwd()
# Out:
# '/Users/alvastrand/Documents/OU/Research/notebooks'

# %%
path = '/Users/alvastrand/Documents/OU/Research/data/'
os.chdir(path)

# %%
os.getcwd()
# Out:
# '/Users/alvastrand/Documents/OU/Research/data'

# %%
subdir = 'output/'
filename = 'obligate_aerial_insectivores_birdlife_nacc_north_america.csv'
df_a_i = pd.read_csv(subdir + filename)

# %%
subdir = 'ebird/ebd_output/'
filename = 'ebird_taxonomy.csv'
df_e_t = pd.read_csv(subdir + filename)

# %%
print(len(df_a_i))
print(len(df_e_t))
# Out:
# 19
# 16513

# %%
df_a_i.head(2)
# Out:
#             scientific_name       LON.b      LAT.b      LON.nb     LAT.nb  \
# 0      Antrostomus arizonae -103.398915  24.849878 -100.202682  20.712022
# 1  Antrostomus carolinensis  -88.058904  34.063816  -83.140011  16.459749
#
#    MAX.LAT.nb     distance  intersect    id        avibase id     rank  \
# 0   28.631368   563.581341   0.625247  2061  CED2468C3EF9B42C  species
# 1   30.354784  2011.374172   0.049623   718  8D3E887123F5C670  species
#
#               common_name              french_name             order  \
# 0  Mexican Whip-poor-will    Engoulevent d'Arizona  Caprimulgiformes
# 1      Chuck-will's-widow  Engoulevent de Caroline  Caprimulgiformes
#
#           family      subfamily        genus  annotation  status_accidental  \
# 0  Caprimulgidae  Caprimulginae  Antrostomus         NaN                NaN
# 1  Caprimulgidae  Caprimulginae  Antrostomus  Monotypic.                NaN
#
#    status_hawaiian  status_introduced  status_nonbreeding  status_extinct  \
# ...

# %%
df_e_t.head(2)
# Out:
#           scientific_name     common_name species_code category  taxon_order  \
# 0        Struthio camelus  Common Ostrich      ostric2  species            1
# 1  Struthio molybdophanes  Somali Ostrich      ostric3  species            6
#
#               order         family report_as
# 0  Struthioniformes  Struthionidae       NaN
# 1  Struthioniformes  Struthionidae       NaN

# %%
df_a_i_e_t = df_a_i[['scientific_name', 'common_name']].merge(df_e_t, on=['scientific_name', 'common_name'])

# %%
len(df_a_i_e_t)
# Out:
# 19

# %%
df_a_i_e_t.head(2)
# Out:
#             scientific_name             common_name species_code category  \
# 0      Antrostomus arizonae  Mexican Whip-poor-will      souwpw1  species
# 1  Antrostomus carolinensis      Chuck-will's-widow       chwwid  species
#
#    taxon_order             order         family report_as
# 0         3533  Caprimulgiformes  Caprimulgidae       NaN
# 1         3510  Caprimulgiformes  Caprimulgidae       NaN

# %%
df_a_i_e_t
# Out:
#                scientific_name                    common_name species_code  \
# 0         Antrostomus arizonae         Mexican Whip-poor-will      souwpw1
# 1     Antrostomus carolinensis             Chuck-will's-widow       chwwid
# 2         Antrostomus ridgwayi         Buff-collared Nightjar       bucnig
# 3        Antrostomus vociferus         Eastern Whip-poor-will      whip-p1
# 4       Chordeiles acutipennis               Lesser Nighthawk       lesnig
# 5             Chordeiles minor               Common Nighthawk       comnig
# 6     Phalaenoptilus nuttallii                Common Poorwill       compoo
# 7         Aeronautes saxatalis           White-throated Swift       whtswi
# 8            Chaetura pelagica                  Chimney Swift       chiswi
# 9               Chaetura vauxi                   Vaux's Swift       vauswi
# 10           Cypseloides niger                    Black Swift       blkswi
# ...

# %%
subdir = 'output/'
filename = 'obligate_aerial_insectivores_ebird_species_codes.csv'
# df_a_i_e_t.to_csv(subdir + filename, index=False)
