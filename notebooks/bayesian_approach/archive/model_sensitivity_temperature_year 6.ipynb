# %%
import os
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from statsmodels.graphics.regressionplots import abline_plot
import matplotlib
import geopandas
from scipy import stats
import seaborn as sns
import matplotlib.patches as mpl_patches
import matplotlib as mpl

# %%
mpl.rcParams['axes.labelsize']
# Out:
# 'medium'

# %%
pd.options.display.max_columns = 100

# %%
os.getcwd()
# Out:
# '/Users/alvastrand/Library/Mobile Documents/com~apple~CloudDocs/Documents/OU/Research/notebooks/Casey'

# %%
# Per species:
# Day ~ Temperature + (Temperature | Cell)

# %%
path = '/Users/alvastrand/Downloads/linear_mixed_modeling/mean_arrival_day_temperature/coefficients/'

os.chdir(path)

# %%
os.getcwd()
# Out:
# '/Users/alvastrand/Downloads/linear_mixed_modeling/mean_arrival_day_temperature/coefficients'

# %%
filename = 'coefficients_mean_arrival_day_temperature.csv'

df_coeffs_lmer = pd.read_csv(filename)
print(df_coeffs_lmer.shape)

df_coeffs_lmer.head(2)
# Out:
# (450, 4)
#                     species  cell     slope   intercept
# 0  Antrostomus_carolinensis    19 -1.749315  101.853281
# 1  Antrostomus_carolinensis    45 -0.959714  105.110310

# %%
os.getcwd()
# Out:
# '/Users/alvastrand/Downloads/linear_mixed_modeling/mean_arrival_day_temperature/coefficients'

# %%
path = '/Users/alvastrand/Library/Mobile Documents/com~apple~CloudDocs/Documents/OU/Research/data/output/'

os.chdir(path)

# %%
os.getcwd()
# Out:
# '/Users/alvastrand/Library/Mobile Documents/com~apple~CloudDocs/Documents/OU/Research/data/output'

# %%
filename = 'aerial_insectivores_migration_distances_mean_weighted_body_masses.csv'

df_common_names = pd.read_csv(filename)
print(df_common_names.shape)

df_common_names.head(2)
# Out:
# (19, 26)
#             scientific_name       LON.b      LAT.b      LON.nb     LAT.nb  \
# 0      Aeronautes saxatalis -108.698701  32.448050 -105.931063  26.265097
# 1  Antrostomus carolinensis  -88.058904  34.063816  -83.140011  16.459749
#
#    MAX.LAT.nb     distance  intersect   id        avibase id     rank  \
# 0   39.513228   736.046352   0.586364  755  B401C2DDB3ED732D  species
# 1   30.354784  2011.374172   0.049623  718  8D3E887123F5C670  species
#
#             common_name               french_name             order  \
# 0  White-throated Swift  Martinet à gorge blanche       Apodiformes
# 1    Chuck-will's-widow   Engoulevent de Caroline  Caprimulgiformes
#
#           family      subfamily        genus  annotation  status_accidental  \
# 0       Apodidae       Apodinae   Aeronautes         NaN                NaN
# 1  Caprimulgidae  Caprimulginae  Antrostomus  Monotypic.                NaN
#
#    status_hawaiian  status_introduced  status_nonbreeding  status_extinct  \
# 0              NaN                NaN                 NaN             NaN
# 1              NaN                NaN                 NaN             NaN
#
#    status_misplaced order_birds_of_north_america  body_mass
# 0               NaN             Caprimulgiformes       32.1
# 1               NaN             Caprimulgiformes      109.0

# %%
df_common_names = df_common_names[['scientific_name', 'common_name']]
print(df_common_names.shape)

df_common_names.head(2)
# Out:
# (19, 2)
#             scientific_name           common_name
# 0      Aeronautes saxatalis  White-throated Swift
# 1  Antrostomus carolinensis    Chuck-will's-widow

# %%
# Per cell:
# Temperature ~ Year

# %%
path = '/Users/alvastrand/Library/Mobile Documents/com~apple~CloudDocs/Documents/OU/Research/data/output/'

os.chdir(path)

# %%
os.getcwd()
# Out:
# '/Users/alvastrand/Library/Mobile Documents/com~apple~CloudDocs/Documents/OU/Research/data/output'

# %%
filename = 'betas_temperature_year_ols.csv'

df_temp_change = pd.read_csv(filename)
print(df_temp_change.shape)

df_temp_change.head(2)
# Out:
# (182, 8)
#    cell  slope_temp_change_all_years  standard_error_temp_change_all_years  \
# 0     0                     0.047530                              0.039869
# 1     1                     0.050006                              0.037956
#
#    intercept_temp_change_all_years  p_value_temp_change_all_years  \
# 0                       -74.496379                       0.250578
# 1                       -79.129506                       0.206236
#
#    r_squared_temp_change_all_years  lower_conf_int_temp_change_all_years  \
# 0                         0.081582                             -0.036988
# 1                         0.097866                             -0.030457
#
#    upper_conf_int_temp_change_all_years
# 0                              0.132049
# 1                              0.130469

# %%
# Per cell:
# Temperature ~ Year
# Range of years

# %%
path = '/Users/alvastrand/Downloads/states_21basic/'

os.chdir(path)

# %%
os.getcwd()
# Out:
# '/Users/alvastrand/Downloads/states_21basic'

# %%
filename = 'aerial_insectivores_betas_temperature_year_years_ols.csv'

df_temp_change_years = pd.read_csv(filename)
print(df_temp_change_years.shape)

df_temp_change_years.head(2)
# Out:
# (450, 11)
#                     species  cell  earliest_year  latest_year  \
# 0  Antrostomus_carolinensis    19           2010         2017
# 1  Antrostomus_carolinensis    45           2014         2019
#
#    slope_temp_year_years  standard_error_temp_year_years  \
# 0               0.310525                        0.185129
# 1               0.303084                        0.143583
#
#    intercept_temp_year_years  p_value_temp_year_years  \
# 0                -610.402682                 0.144486
# 1                -600.626366                 0.102391
#
#    r_squared_temp_year_years  lower_conf_int_temp_year_years  \
# 0                   0.319225                       -0.142469
# 1                   0.526948                       -0.095567
#
#    upper_conf_int_temp_year_years
# 0                        0.763518
# 1                        0.701736

# %%
# Per species:
# Temperature ~ Year + (Year | Cell)
# Range of years?

# %%
path = '/Users/alvastrand/Downloads/linear_mixed_modeling/temperature_year/coefficients/'

os.chdir(path)

# %%
os.getcwd()
# Out:
# '/Users/alvastrand/Downloads/linear_mixed_modeling/temperature_year/coefficients'

# %%
filename = 'coefficients_temperature_year.csv'

df_temp_change_lmer = pd.read_csv(filename)

print(df_temp_change_lmer.shape)

df_temp_change_lmer.head(2)
# Out:
# (182, 3)
#    cell     slope  intercept
# 0     0  0.038108 -55.566823
# 1     1  0.038259 -55.527943

# %%
df_temp_change_lmer = df_temp_change_lmer.rename(columns={'slope': 'slope_temp_change_lmer', 
                                                     'intercept': 'intercept_temp_change_lmer'})
print(df_temp_change_lmer.shape)

df_temp_change_lmer.head(2)
# Out:
# (182, 3)
#    cell  slope_temp_change_lmer  intercept_temp_change_lmer
# 0     0                0.038108                  -55.566823
# 1     1                0.038259                  -55.527943

# %%
df_comparison = df_temp_change.merge(df_temp_change_lmer, on='cell')
print(df_comparison.shape)

df_comparison.head(2)
# Out:
# (182, 10)
#    cell  slope_temp_change_all_years  standard_error_temp_change_all_years  \
# 0     0                     0.047530                              0.039869
# 1     1                     0.050006                              0.037956
#
#    intercept_temp_change_all_years  p_value_temp_change_all_years  \
# 0                       -74.496379                       0.250578
# 1                       -79.129506                       0.206236
#
#    r_squared_temp_change_all_years  lower_conf_int_temp_change_all_years  \
# 0                         0.081582                             -0.036988
# 1                         0.097866                             -0.030457
#
#    upper_conf_int_temp_change_all_years  slope_temp_change_lmer  \
# 0                              0.132049                0.038108
# 1                              0.130469                0.038259
#
#    intercept_temp_change_lmer
# 0                  -55.566823
# 1                  -55.527943

# %%
fig, ax = plt.subplots(figsize=(6, 6))

df_comparison.plot.scatter(x='slope_temp_change_all_years', y='slope_temp_change_lmer', ax=ax)

low_x, high_x = ax.get_xlim()
# print(low_x, high_x)

low_y, high_y = ax.get_ylim()
# print(low_y, high_y)

low = min(low_x, low_y)
print(low)

high = max(high_x, high_y)
print(high)

ax.set_xlim(low, high)
ax.set_ylim(low, high)

ax.plot([0, 1], [0, 1], linestyle='dashed', transform=ax.transAxes)

plt.show()
# Out:
# -0.09761216696758983
# 0.12093667528553893

# %%
fig, ax = plt.subplots(figsize=(6, 6))

df_comparison.plot.scatter(x='intercept_temp_change_all_years', y='intercept_temp_change_lmer', ax=ax)

low_x, high_x = ax.get_xlim()
# print(low_x, high_x)

low_y, high_y = ax.get_ylim()
# print(low_y, high_y)

low = min(low_x, low_y)
print(low)

high = max(high_x, high_y)
print(high)

ax.set_xlim(low, high)
ax.set_ylim(low, high)

ax.plot([0, 1], [0, 1], linestyle='dashed', transform=ax.transAxes)

plt.show()
# Out:
# -246.80221562200194
# 190.04023441768496

# %%
df_sens_temp_change = df_coeffs_lmer.merge(df_temp_change, on='cell')
print(df_sens_temp_change.shape)

df_sens_temp_change.head(2)
# Out:
# (450, 11)
#                     species  cell     slope   intercept  \
# 0  Antrostomus_carolinensis    19 -1.749315  101.853281
# 1         Chaetura_pelagica    19 -0.277597  107.545694
#
#    slope_temp_change_all_years  standard_error_temp_change_all_years  \
# 0                     0.060397                              0.062364
# 1                     0.060397                              0.062364
#
#    intercept_temp_change_all_years  p_value_temp_change_all_years  \
# 0                       -106.61285                       0.347229
# 1                       -106.61285                       0.347229
#
#    r_squared_temp_change_all_years  lower_conf_int_temp_change_all_years  \
# 0                         0.055373                             -0.071809
# 1                         0.055373                             -0.071809
#
#    upper_conf_int_temp_change_all_years
# 0                              0.192604
# 1                              0.192604

# %%
df_sens_temp_change = df_sens_temp_change.rename(columns={'species': 'scientific_name'})

df_sens_temp_change['scientific_name'] = df_sens_temp_change['scientific_name'].str.replace('_', ' ')

print(df_sens_temp_change.shape)

df_sens_temp_change.head(2)
# Out:
# (450, 11)
#             scientific_name  cell     slope   intercept  \
# 0  Antrostomus carolinensis    19 -1.749315  101.853281
# 1         Chaetura pelagica    19 -0.277597  107.545694
#
#    slope_temp_change_all_years  standard_error_temp_change_all_years  \
# 0                     0.060397                              0.062364
# 1                     0.060397                              0.062364
#
#    intercept_temp_change_all_years  p_value_temp_change_all_years  \
# 0                       -106.61285                       0.347229
# 1                       -106.61285                       0.347229
#
#    r_squared_temp_change_all_years  lower_conf_int_temp_change_all_years  \
# 0                         0.055373                             -0.071809
# 1                         0.055373                             -0.071809
#
#    upper_conf_int_temp_change_all_years
# 0                              0.192604
# 1                              0.192604

# %%
df_sens_temp_change = df_sens_temp_change.merge(df_common_names, on='scientific_name')
print(df_sens_temp_change.shape)

df_sens_temp_change.head(2)
# Out:
# (450, 12)
#             scientific_name  cell     slope   intercept  \
# 0  Antrostomus carolinensis    19 -1.749315  101.853281
# 1  Antrostomus carolinensis    45 -0.959714  105.110310
#
#    slope_temp_change_all_years  standard_error_temp_change_all_years  \
# 0                     0.060397                              0.062364
# 1                     0.094084                              0.053247
#
#    intercept_temp_change_all_years  p_value_temp_change_all_years  \
# 0                      -106.612850                       0.347229
# 1                      -179.479664                       0.096304
#
#    r_squared_temp_change_all_years  lower_conf_int_temp_change_all_years  \
# 0                         0.055373                             -0.071809
# 1                         0.163271                             -0.018794
#
#    upper_conf_int_temp_change_all_years         common_name
# 0                              0.192604  Chuck-will's-widow
# 1                              0.206962  Chuck-will's-widow

# %%
df_sens_temp_change_years = df_coeffs_lmer.merge(df_temp_change_years, on=['species', 'cell'])
print(df_sens_temp_change_years.shape)

df_sens_temp_change_years.head(2)
# Out:
# (450, 13)
#                     species  cell     slope   intercept  earliest_year  \
# 0  Antrostomus_carolinensis    19 -1.749315  101.853281           2010
# 1  Antrostomus_carolinensis    45 -0.959714  105.110310           2014
#
#    latest_year  slope_temp_year_years  standard_error_temp_year_years  \
# 0         2017               0.310525                        0.185129
# 1         2019               0.303084                        0.143583
#
#    intercept_temp_year_years  p_value_temp_year_years  \
# 0                -610.402682                 0.144486
# 1                -600.626366                 0.102391
#
#    r_squared_temp_year_years  lower_conf_int_temp_year_years  \
# 0                   0.319225                       -0.142469
# 1                   0.526948                       -0.095567
#
#    upper_conf_int_temp_year_years
# 0                        0.763518
# 1                        0.701736

# %%
df_sens_temp_change_years = df_sens_temp_change_years.rename(columns={'species': 'scientific_name'})

df_sens_temp_change_years['scientific_name'] = df_sens_temp_change_years['scientific_name'].str.replace('_', ' ')

print(df_sens_temp_change_years.shape)

df_sens_temp_change_years.head(2)
# Out:
# (450, 13)
#             scientific_name  cell     slope   intercept  earliest_year  \
# 0  Antrostomus carolinensis    19 -1.749315  101.853281           2010
# 1  Antrostomus carolinensis    45 -0.959714  105.110310           2014
#
#    latest_year  slope_temp_year_years  standard_error_temp_year_years  \
# 0         2017               0.310525                        0.185129
# 1         2019               0.303084                        0.143583
#
#    intercept_temp_year_years  p_value_temp_year_years  \
# 0                -610.402682                 0.144486
# 1                -600.626366                 0.102391
#
#    r_squared_temp_year_years  lower_conf_int_temp_year_years  \
# 0                   0.319225                       -0.142469
# 1                   0.526948                       -0.095567
#
#    upper_conf_int_temp_year_years
# 0                        0.763518
# 1                        0.701736

# %%
df_sens_temp_change_years = df_sens_temp_change_years.merge(df_common_names, on='scientific_name')
print(df_sens_temp_change_years.shape)

df_sens_temp_change_years.head(2)
# Out:
# (450, 14)
#             scientific_name  cell     slope   intercept  earliest_year  \
# 0  Antrostomus carolinensis    19 -1.749315  101.853281           2010
# 1  Antrostomus carolinensis    45 -0.959714  105.110310           2014
#
#    latest_year  slope_temp_year_years  standard_error_temp_year_years  \
# 0         2017               0.310525                        0.185129
# 1         2019               0.303084                        0.143583
#
#    intercept_temp_year_years  p_value_temp_year_years  \
# 0                -610.402682                 0.144486
# 1                -600.626366                 0.102391
#
#    r_squared_temp_year_years  lower_conf_int_temp_year_years  \
# 0                   0.319225                       -0.142469
# 1                   0.526948                       -0.095567
#
#    upper_conf_int_temp_year_years         common_name
# 0                        0.763518  Chuck-will's-widow
# 1                        0.701736  Chuck-will's-widow

# %%
df_sens_temp_change_years = df_sens_temp_change_years.sort_values(by='common_name')
print(df_sens_temp_change_years.shape)

df_sens_temp_change_years
# Out:
# (450, 14)
#          scientific_name  cell     slope   intercept  earliest_year  \
# 320      Riparia riparia   135 -0.092641  119.042868           2009
# 327      Riparia riparia   147 -0.223518  123.682182           2008
# 326      Riparia riparia   144 -0.125033  121.429378           2014
# 325      Riparia riparia   143 -0.167981  125.744081           2011
# 324      Riparia riparia   142  0.050361  123.721246           2012
# ..                   ...   ...       ...         ...            ...
# 417  Tachycineta bicolor   121 -0.980666   90.513007           2002
# 418  Tachycineta bicolor   122 -0.900074  100.809319           2008
# 419  Tachycineta bicolor   127 -0.994682   88.722460           2007
# 408  Tachycineta bicolor   105 -1.059980   80.380041           2002
# 449  Tachycineta bicolor   170 -0.875378  103.964563           2014
#
#      latest_year  slope_temp_year_years  standard_error_temp_year_years  \
# 320         2019              -0.150581                        0.204604
# 327         2019              -0.107240                        0.185394
# 326         2019               0.820280                        0.589293
# 325         2019              -0.078230                        0.365376
# 324         2019              -0.208836                        0.465778
# ..           ...                    ...                             ...
# 417         2012               0.141711                        0.120469
# 418         2019              -0.072460                        0.121890
# 419         2019              -0.004753                        0.191604
# 408         2019               0.015208                        0.060328
# 449         2018               0.700335                        0.691919
#
#      intercept_temp_year_years  p_value_temp_year_years  \
# 320                 299.131612                 0.480495
# 327                 210.569785                 0.575759
# 326               -1659.795963                 0.236333
# 325                 153.046101                 0.836566
# 324                 415.234669                 0.669630
# ..                         ...                      ...
# 417                -284.734778                 0.269640
# 418                 149.058177                 0.565403
# 419                   6.028264                 0.980653
# 408                 -29.525893                 0.804176
# 449               -1423.053491                 0.386003
#
#      r_squared_temp_year_years  lower_conf_int_temp_year_years  \
# 320                   0.056766                       -0.613428
# 327                   0.032376                       -0.520325
# 326                   0.326325                       -0.815861
# 325                   0.006506                       -0.942207
# 324                   0.032418                       -1.348554
# ..                         ...                             ...
# 417                   0.133261                       -0.130808
# 418                   0.034133                       -0.344048
# 419                   0.000056                       -0.426471
# 408                   0.003956                       -0.112681
# 449                   0.254561                       -1.501660
#
#      upper_conf_int_temp_year_years   common_name
# 320                        0.312266  Bank Swallow
# 327                        0.305844  Bank Swallow
# 326                        2.456420  Bank Swallow
# 325                        0.785747  Bank Swallow
# 324                        0.930881  Bank Swallow
# ..                              ...           ...
# 417                        0.414229  Tree Swallow
# 418                        0.199128  Tree Swallow
# 419                        0.416965  Tree Swallow
# 408                        0.143097  Tree Swallow
# 449                        2.902331  Tree Swallow
#
# [450 rows x 14 columns]

# %%
df_temp_change_lmer.head(2)
# Out:
#    cell  slope_temp_change_lmer  intercept_temp_change_lmer
# 0     0                0.038108                  -55.566823
# 1     1                0.038259                  -55.527943

# %%
df_sens_temp_change_lmer = df_coeffs_lmer.merge(df_temp_change_lmer, on='cell')
print(df_sens_temp_change_lmer.shape)

df_sens_temp_change_lmer.head(2)
# Out:
# (450, 6)
#                     species  cell     slope   intercept  \
# 0  Antrostomus_carolinensis    19 -1.749315  101.853281
# 1         Chaetura_pelagica    19 -0.277597  107.545694
#
#    slope_temp_change_lmer  intercept_temp_change_lmer
# 0                0.035354                  -56.272521
# 1                0.035354                  -56.272521

# %%
df_sens_temp_change_lmer = df_sens_temp_change_lmer.rename(columns={'species': 'scientific_name'})

df_sens_temp_change_lmer['scientific_name'] = df_sens_temp_change_lmer['scientific_name'].str.replace('_', ' ')

print(df_sens_temp_change_lmer.shape)

df_sens_temp_change_lmer.head(2)
# Out:
# (450, 6)
#             scientific_name  cell     slope   intercept  \
# 0  Antrostomus carolinensis    19 -1.749315  101.853281
# 1         Chaetura pelagica    19 -0.277597  107.545694
#
#    slope_temp_change_lmer  intercept_temp_change_lmer
# 0                0.035354                  -56.272521
# 1                0.035354                  -56.272521

# %%
df_sens_temp_change_lmer = df_sens_temp_change_lmer.merge(df_common_names, on='scientific_name')
print(df_sens_temp_change_lmer.shape)

df_sens_temp_change_lmer.head(2)
# Out:
# (450, 7)
#             scientific_name  cell     slope   intercept  \
# 0  Antrostomus carolinensis    19 -1.749315  101.853281
# 1  Antrostomus carolinensis    45 -0.959714  105.110310
#
#    slope_temp_change_lmer  intercept_temp_change_lmer         common_name
# 0                0.035354                  -56.272521  Chuck-will's-widow
# 1                0.033089                  -56.853124  Chuck-will's-widow

# %%
list_species_names = list(sorted(df_sens_temp_change['scientific_name'].unique()))
print(len(list_species_names))
print(list_species_names)
# Out:
# 10
# ['Antrostomus carolinensis', 'Antrostomus vociferus', 'Chaetura pelagica', 'Chordeiles minor', 'Hirundo rustica', 'Petrochelidon pyrrhonota', 'Progne subis', 'Riparia riparia', 'Stelgidopteryx serripennis', 'Tachycineta bicolor']

# %%
def run_ols_regression(df, predictor_variable, column_name, species, left_xlim, right_xlim, left_ylim, right_ylim):
    
    common_name = df['common_name'].unique()[0]

    model_ols = smf.ols(formula=column_name + ' ~ ' + predictor_variable, data=df)

    res_ols = model_ols.fit()
    
    print(res_ols.summary())
    
    slope = res_ols.params[1]
#     print(slope)

    standard_error = res_ols.bse.iloc[1]
    
    intercept = res_ols.params[0]
#     print(intercept)

    r_squared = res_ols.rsquared
#     print(r_squared)

    p_value = res_ols.pvalues[1]
#     print(p_value)
    
    conf_int = [res_ols.conf_int().iloc[1].iloc[0], res_ols.conf_int().iloc[1].iloc[1]]
    
    lower_conf_int = conf_int[0]
    
    upper_conf_int = conf_int[1]
    
    g = sns.lmplot(data=df, x=predictor_variable, y=column_name)
    
#     line_kws={'label':"y={0:.1f}x+{1:.1f}".format(slope, intercept)}
        
    for ax in g.axes.flat:
        
        print(ax.get_xlim())
        print(ax.get_ylim())
        
#     g.set(ylim=(left_ylim, right_ylim))
        
    g.set(xlim=(left_xlim, right_xlim), ylim=(left_ylim, right_ylim))
    
    for ax in g.axes.flat:
        
        print(ax.get_xlim())
        print(ax.get_ylim())
        
    plt.axhline(y=0, color='0.8', linestyle='--')
    
    handles = [mpl_patches.Rectangle((0, 0), 1, 1, fc="white", ec="white", 
                                 lw=0, alpha=0)] * 3
    
    labels = []
    
    labels.append('beta = {0:.3g} \u00B1 {1:.3g}'.format(slope, standard_error))
    
    if p_value < 0.001:
        labels.append("P < 0.001")
    else:
        labels.append("P = {0:.3g}".format(p_value))
        
    labels.append("R^2 = {0:.3g}".format(r_squared))
    
    plt.legend(handles, labels, loc='best', 
          fancybox=True, framealpha=0.7, 
          handlelength=0, handletextpad=0)
        
#     fontsize
                
    plt.xlabel('Air temperature change over time (°C/year)')
    
    plt.ylabel('Sensitivity (Julian days/°C)')
    
#     plt.title(common_name)
    
#     plt.show()

    print(g.figure.get_size_inches())
    
    plt.savefig('/Users/alvastrand/Downloads/AOS_2023/Figures/sensitivity_temperature_year/' + common_name + '.pdf', 
                bbox_inches='tight')
    
    return common_name, slope, p_value, lower_conf_int, upper_conf_int

# %%
def test_function(df, predictor_variable, column_name, species, left_xlim, right_xlim, left_ylim, right_ylim):
    
    common_name = df['common_name'].unique()[0]

    model_ols = smf.ols(formula=column_name + ' ~ ' + predictor_variable, data=df)

    res_ols = model_ols.fit()
    
    print(res_ols.summary())
    
    slope = res_ols.params[1]
#     print(slope)

    standard_error = res_ols.bse.iloc[1]
    
    intercept = res_ols.params[0]
#     print(intercept)

    r_squared = res_ols.rsquared
#     print(r_squared)

    p_value = res_ols.pvalues[1]
#     print(p_value)
    
    conf_int = [res_ols.conf_int().iloc[1].iloc[0], res_ols.conf_int().iloc[1].iloc[1]]
    
    lower_conf_int = conf_int[0]
    
    upper_conf_int = conf_int[1]
    
    fig, ax = plt.subplots(figsize=(4.76*1.5, 4.76))
    
    plt.subplots_adjust(right=0.8)
    
    sns.regplot(data=df, x=predictor_variable, y=column_name, ax=ax)
    
    plt.tick_params(labelsize=16)
    
#     line_kws={'label':"y={0:.1f}x+{1:.1f}".format(slope, intercept)}
        
#     for ax in g.axes.flat:
        
#         print(ax.get_xlim())
#         print(ax.get_ylim())
    
    ax.set_xlim(left_xlim, right_xlim)
    ax.set_ylim(left_ylim, right_ylim)
    
#     for ax in g.axes.flat:
        
#         print(ax.get_xlim())
#         print(ax.get_ylim())
        
    plt.axhline(y=0, color='0.8', linestyle='--')
    
    plt.axvline(x=0, color='0.8', linestyle='--')
    
    handles = [mpl_patches.Rectangle((0, 0), 1, 1, fc="white", ec="white", 
                                 lw=0, alpha=0)] * 3
    
    labels = []
    
    labels.append('$\u03B2$ = {0:.3g} \u00B1 {1:.3g}'.format(slope, standard_error))
    
    if p_value < 0.001:
        labels.append("$P$ < 0.001")
    else:
        labels.append("$P$ = {0:.3g}".format(p_value))
        
    labels.append("$R^2$ = {0:.3g}".format(r_squared))
    
    plt.legend(handles, labels, loc='best', 
          fancybox=True, framealpha=0.8, 
          handlelength=0, handletextpad=0, fontsize=16)
        
#     fontsize

    plt.xticks([-0.05, 0, 0.05])
                
    plt.xlabel('Air temperature change over time (°C/year)', fontsize=16)
    
    plt.ylabel('Sensitivity (Julian days/°C)', fontsize=16)
    
    plt.title(common_name, fontsize=18)
    
#     plt.tight_layout()
    
    plt.show()
    
#     print(g.figure.get_size_inches())
    
    plt.savefig('/Users/alvastrand/Downloads/AOS_2023/Figures/sensitivity_temperature_year/' + common_name + '_test' + '.pdf', 
                bbox_inches='tight')
    
#     plt.savefig('/Users/alvastrand/Downloads/AOS_2023/Figures/sensitivity_temperature_year/' + common_name + '_test' + '.svg', 
#                 bbox_inches='tight')
    
    return common_name, slope, p_value, r_squared, lower_conf_int, upper_conf_int

# %%
# for species in list_species_names:
    
#     print(species)
    
#     left_ylim = df_sens_temp_change['slope'].min()
# #     print(left_ylim)

#     right_ylim = df_sens_temp_change['slope'].max()
# #     print(right_ylim)
    
#     df_species = df_sens_temp_change[df_sens_temp_change['scientific_name'] == species]
    
#     predictor_variable = 'slope_temp_change_all_years'

#     column_name = 'slope'

#     run_ols_regression(df_species, predictor_variable, column_name, species, left_ylim, right_ylim)

# %%
left_ylim = df_sens_temp_change_lmer['slope'].min()
print(left_ylim)

right_ylim = df_sens_temp_change_lmer['slope'].max()
print(right_ylim)

left_xlim = df_sens_temp_change_lmer['slope_temp_change_lmer'].min()
print(left_xlim)

right_xlim = df_sens_temp_change_lmer['slope_temp_change_lmer'].max()
print(right_xlim)
# Out:
# -1.74931474675599
# 1.06180419178181
# 0.0242735638409362
# 0.0375774678175229

# %%
# list_common_names = []
# list_slopes = []
# list_p_values = []
# list_lower_conf_ints = []
# list_upper_conf_ints = []

# for species in list_species_names:
    
#     print(species)
    
#     df_species = df_sens_temp_change_lmer[df_sens_temp_change_lmer['scientific_name'] == species]
    
# #     print(df_species['slope'].min())
# #     print(df_species['slope'].max())
    
#     print(df_species['slope_temp_change_lmer'].min())
#     print(df_species['slope_temp_change_lmer'].max())
    
#     # Tree Swallow
#     left_xlim = 0.023949626088802505
    
#     # Barn Swallow
#     right_xlim = 0.03820387900887928
    
#     # Space?
    
#     left_ylim = -2.343200965850084
#     right_ylim = 1.2239472945261858

#     predictor_variable = 'slope_temp_change_lmer'

#     column_name = 'slope'

#     common_name, slope, p_value, lower_conf_int, upper_conf_int = run_ols_regression(df_species, 
#                                                                                      predictor_variable, 
#                                                                                      column_name, 
#                                                                                      species, 
#                                                                                      left_xlim, 
#                                                                                      right_xlim, 
#                                                                                      left_ylim, 
#                                                                                      right_ylim)
    
#     list_common_names.append(common_name)
#     list_slopes.append(slope)
#     list_p_values.append(p_value)
#     list_lower_conf_ints.append(lower_conf_int)
#     list_upper_conf_ints.append(upper_conf_int)

# %%
# list_common_names = []
# list_slopes = []
# list_p_values = []
# list_r_squared = []
# list_lower_conf_ints = []
# list_upper_conf_ints = []

# for species in list_species_names:
    
#     print(species)
    
#     df_species = df_sens_temp_change_lmer[df_sens_temp_change_lmer['scientific_name'] == species]
    
# #     print(df_species['slope'].min())
# #     print(df_species['slope'].max())
    
#     print(df_species['slope_temp_change_lmer'].min())
#     print(df_species['slope_temp_change_lmer'].max())
    
#     # Tree Swallow
#     left_xlim = 0.023949626088802505
    
#     # Barn Swallow
#     right_xlim = 0.03820387900887928
    
#     # Space?
    
#     left_ylim = -2.343200965850084
#     right_ylim = 1.2239472945261858

#     predictor_variable = 'slope_temp_change_lmer'

#     column_name = 'slope'

#     common_name, slope, p_value, r_squared, lower_conf_int, upper_conf_int = test_function(df_species, 
#                                                                                      predictor_variable, 
#                                                                                      column_name, 
#                                                                                      species, 
#                                                                                      left_xlim, 
#                                                                                      right_xlim, 
#                                                                                      left_ylim, 
#                                                                                      right_ylim)
    
#     list_common_names.append(common_name)
#     list_slopes.append(slope)
#     list_p_values.append(p_value)
#     list_r_squared.append(r_squared)
#     list_lower_conf_ints.append(lower_conf_int)
#     list_upper_conf_ints.append(upper_conf_int)

# %%
list_common_names = []
list_slopes = []
list_p_values = []
list_r_squared = []
list_lower_conf_ints = []
list_upper_conf_ints = []

for species in list_species_names:
    
    print(species)
    
    df_species = df_sens_temp_change[df_sens_temp_change['scientific_name'] == species]
    
    print(df_species['slope'].min())
    print(df_species['slope'].max())
    
    print(df_species['slope_temp_change_all_years'].min())
    print(df_species['slope_temp_change_all_years'].max())

    left_xlim = df_sens_temp_change['slope_temp_change_all_years'].min()
    print(left_xlim)

    right_xlim = df_sens_temp_change['slope_temp_change_all_years'].max()
    print(right_xlim)
    
    left_ylim = df_sens_temp_change['slope'].min()
    print(left_ylim)

    right_ylim = df_sens_temp_change['slope'].max()
    print(right_ylim)

    predictor_variable = 'slope_temp_change_all_years'

    column_name = 'slope'

    common_name, slope, p_value, r_squared, lower_conf_int, upper_conf_int = test_function(df_species, 
                                                                                     predictor_variable, 
                                                                                     column_name, 
                                                                                     species, 
                                                                                     left_xlim, 
                                                                                     right_xlim, 
                                                                                     left_ylim, 
                                                                                     right_ylim)
    
    list_common_names.append(common_name)
    list_slopes.append(slope)
    list_p_values.append(p_value)
    list_r_squared.append(r_squared)
    list_lower_conf_ints.append(lower_conf_int)
    list_upper_conf_ints.append(upper_conf_int)
# Out:
# Antrostomus carolinensis
# -1.74931474675599
# 1.06180419178181
# -0.0074503057010593
# 0.0940837947221761
# -0.0876781286833567
# 0.0940837947221761
# -1.74931474675599
# 1.06180419178181
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  slope   R-squared:                       0.628
# Model:                            OLS   Adj. R-squared:                  0.608
# Method:                 Least Squares   F-statistic:                     32.08
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):           1.85e-05
# Time:                        12:04:46   Log-Likelihood:                -11.815
# No. Observations:                  21   AIC:                             27.63
# Df Residuals:                      19   BIC:                             29.72
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.3781      0.171      2.216      0.039       0.021       0.735
# slope_temp_change_all_years   -19.2689      3.402     -5.664      0.000     -26.389     -12.148
# ==============================================================================
# Omnibus:                        0.106   Durbin-Watson:                   1.509
# Prob(Omnibus):                  0.949   Jarque-Bera (JB):                0.040
# Skew:                           0.021   Prob(JB):                        0.980
# Kurtosis:                       2.790   Cond. No.                         35.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Antrostomus vociferus
# -0.463425789773717
# 0.0560723498296934
# -0.0696081062684962
# 0.0485811494925087
# -0.0876781286833567
# 0.0940837947221761
# -1.74931474675599
# 1.06180419178181
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  slope   R-squared:                       0.558
# Model:                            OLS   Adj. R-squared:                  0.538
# Method:                 Least Squares   F-statistic:                     27.81
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):           2.72e-05
# Time:                        12:04:47   Log-Likelihood:                 23.654
# No. Observations:                  24   AIC:                            -43.31
# Df Residuals:                      22   BIC:                            -40.95
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.1522      0.020     -7.744      0.000      -0.193      -0.111
# slope_temp_change_all_years    -3.3397      0.633     -5.274      0.000      -4.653      -2.026
# ==============================================================================
# Omnibus:                        0.614   Durbin-Watson:                   1.586
# Prob(Omnibus):                  0.736   Jarque-Bera (JB):                0.693
# Skew:                           0.293   Prob(JB):                        0.707
# Kurtosis:                       2.409   Cond. No.                         32.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Chaetura pelagica
# -0.441353558955243
# 0.224021583367523
# -0.0876781286833567
# 0.0940837947221761
# -0.0876781286833567
# 0.0940837947221761
# -1.74931474675599
# 1.06180419178181
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  slope   R-squared:                       0.625
# Model:                            OLS   Adj. R-squared:                  0.620
# Method:                 Least Squares   F-statistic:                     113.5
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):           3.83e-16
# Time:                        12:04:47   Log-Likelihood:                 55.223
# No. Observations:                  70   AIC:                            -106.4
# Df Residuals:                      68   BIC:                            -101.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.0462      0.015     -3.105      0.003      -0.076      -0.017
# slope_temp_change_all_years    -3.6759      0.345    -10.655      0.000      -4.364      -2.987
# ==============================================================================
# Omnibus:                        3.961   Durbin-Watson:                   1.262
# Prob(Omnibus):                  0.138   Jarque-Bera (JB):                3.726
# Skew:                           0.563   Prob(JB):                        0.155
# Kurtosis:                       2.899   Cond. No.                         25.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Chordeiles minor
# -0.441810136386255
# 0.435584361406461
# -0.0876781286833567
# 0.0892199392155228
# -0.0876781286833567
# 0.0940837947221761
# -1.74931474675599
# 1.06180419178181
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  slope   R-squared:                       0.492
# Model:                            OLS   Adj. R-squared:                  0.477
# Method:                 Least Squares   F-statistic:                     32.91
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):           1.89e-06
# Time:                        12:04:48   Log-Likelihood:                 13.475
# No. Observations:                  36   AIC:                            -22.95
# Df Residuals:                      34   BIC:                            -19.78
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1163      0.030      3.825      0.001       0.055       0.178
# slope_temp_change_all_years    -4.0039      0.698     -5.737      0.000      -5.422      -2.586
# ==============================================================================
# Omnibus:                        2.053   Durbin-Watson:                   1.525
# Prob(Omnibus):                  0.358   Jarque-Bera (JB):                1.656
# Skew:                           0.520   Prob(JB):                        0.437
# Kurtosis:                       2.851   Cond. No.                         24.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Hirundo rustica
# -0.544101307863075
# -0.0213640847876596
# -0.0876781286833567
# 0.0940837947221761
# -0.0876781286833567
# 0.0940837947221761
# -1.74931474675599
# 1.06180419178181
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  slope   R-squared:                       0.554
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     88.20
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):           4.46e-14
# Time:                        12:04:48   Log-Likelihood:                 78.472
# No. Observations:                  73   AIC:                            -152.9
# Df Residuals:                      71   BIC:                            -148.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.2713      0.011    -25.227      0.000      -0.293      -0.250
# slope_temp_change_all_years    -2.3963      0.255     -9.391      0.000      -2.905      -1.888
# ==============================================================================
# Omnibus:                       34.031   Durbin-Watson:                   1.085
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               92.109
# Skew:                           1.470   Prob(JB):                     9.97e-21
# Kurtosis:                       7.652   Cond. No.                         26.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Petrochelidon pyrrhonota
# -0.433317363709841
# -0.10350352655211
# -0.0876781286833567
# 0.0892199392155228
# -0.0876781286833567
# 0.0940837947221761
# -1.74931474675599
# 1.06180419178181
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  slope   R-squared:                       0.486
# Model:                            OLS   Adj. R-squared:                  0.474
# Method:                 Least Squares   F-statistic:                     38.82
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):           2.03e-07
# Time:                        12:04:48   Log-Likelihood:                 58.172
# No. Observations:                  43   AIC:                            -112.3
# Df Residuals:                      41   BIC:                            -108.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.2585      0.010    -25.651      0.000      -0.279      -0.238
# slope_temp_change_all_years    -1.8002      0.289     -6.231      0.000      -2.384      -1.217
# ==============================================================================
# Omnibus:                        0.542   Durbin-Watson:                   1.821
# Prob(Omnibus):                  0.763   Jarque-Bera (JB):                0.641
# Skew:                          -0.059   Prob(JB):                        0.726
# Kurtosis:                       2.413   Cond. No.                         29.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Progne subis
# -0.0916963459245861
# 0.299686558270093
# -0.0696081062684962
# 0.0542300256787054
# -0.0876781286833567
# 0.0940837947221761
# -1.74931474675599
# 1.06180419178181
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  slope   R-squared:                       0.340
# Model:                            OLS   Adj. R-squared:                  0.320
# Method:                 Least Squares   F-statistic:                     17.01
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):           0.000236
# Time:                        12:04:48   Log-Likelihood:                 36.495
# No. Observations:                  35   AIC:                            -68.99
# Df Residuals:                      33   BIC:                            -65.88
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.0523      0.016      3.308      0.002       0.020       0.084
# slope_temp_change_all_years     2.2515      0.546      4.124      0.000       1.141       3.362
# ==============================================================================
# Omnibus:                        0.849   Durbin-Watson:                   1.803
# Prob(Omnibus):                  0.654   Jarque-Bera (JB):                0.888
# Skew:                           0.243   Prob(JB):                        0.642
# Kurtosis:                       2.389   Cond. No.                         36.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Riparia riparia
# -0.643313764435911
# 0.267998859633308
# -0.0876781286833567
# 0.0892199392155228
# -0.0876781286833567
# 0.0940837947221761
# -1.74931474675599
# 1.06180419178181
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  slope   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.037
# Method:                 Least Squares   F-statistic:                  0.004192
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):              0.949
# Time:                        12:04:49   Log-Likelihood:                 1.1336
# No. Observations:                  29   AIC:                             1.733
# Df Residuals:                      27   BIC:                             4.467
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.1091      0.045     -2.423      0.022      -0.201      -0.017
# slope_temp_change_all_years     0.0883      1.365      0.065      0.949      -2.712       2.888
# ==============================================================================
# Omnibus:                        1.913   Durbin-Watson:                   1.559
# Prob(Omnibus):                  0.384   Jarque-Bera (JB):                1.625
# Skew:                          -0.555   Prob(JB):                        0.444
# Kurtosis:                       2.666   Cond. No.                         30.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Stelgidopteryx serripennis
# -0.921426234168879
# -0.0189704593695323
# -0.0876781286833567
# 0.0940837947221761
# -0.0876781286833567
# 0.0940837947221761
# -1.74931474675599
# 1.06180419178181
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  slope   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                     79.99
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):           8.10e-13
# Time:                        12:04:49   Log-Likelihood:                 19.907
# No. Observations:                  65   AIC:                            -35.81
# Df Residuals:                      63   BIC:                            -31.46
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.4341      0.024    -18.303      0.000      -0.482      -0.387
# slope_temp_change_all_years    -5.5923      0.625     -8.944      0.000      -6.842      -4.343
# ==============================================================================
# Omnibus:                        6.180   Durbin-Watson:                   1.057
# Prob(Omnibus):                  0.045   Jarque-Bera (JB):                2.755
# Skew:                           0.199   Prob(JB):                        0.252
# Kurtosis:                       2.074   Cond. No.                         27.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Tachycineta bicolor
# -1.11911177742481
# -0.855936580707934
# -0.0876781286833567
# 0.0793267769708999
# -0.0876781286833567
# 0.0940837947221761
# -1.74931474675599
# 1.06180419178181
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  slope   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     2.492
# Date:                Sat, 05 Aug 2023   Prob (F-statistic):              0.120
# Time:                        12:04:49   Log-Likelihood:                 68.532
# No. Observations:                  54   AIC:                            -133.1
# Df Residuals:                      52   BIC:                            -129.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -0.9818      0.009   -104.040      0.000      -1.001      -0.963
# slope_temp_change_all_years    -0.5040      0.319     -1.579      0.120      -1.145       0.137
# ==============================================================================
# Omnibus:                        2.812   Durbin-Watson:                   0.614
# Prob(Omnibus):                  0.245   Jarque-Bera (JB):                2.229
# Skew:                           0.356   Prob(JB):                        0.328
# Kurtosis:                       2.305   Cond. No.                         33.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df_betas_sens_temp = pd.DataFrame(data={'scientific_name': list_species_names, 'common_name': list_common_names, 
                                        'slope': list_slopes, 'p_value': list_p_values, 'r_squared': list_r_squared, 
                                        'lower_conf_int': list_lower_conf_ints, 
                                        'upper_conf_int': list_upper_conf_ints})
print(df_betas_sens_temp.shape)

df_betas_sens_temp
# Out:
# (10, 7)
#               scientific_name                    common_name      slope  \
# 0    Antrostomus carolinensis             Chuck-will's-widow -19.268854
# 1       Antrostomus vociferus         Eastern Whip-poor-will  -3.339671
# 2           Chaetura pelagica                  Chimney Swift  -3.675902
# 3            Chordeiles minor               Common Nighthawk  -4.003891
# 4             Hirundo rustica                   Barn Swallow  -2.396291
# 5    Petrochelidon pyrrhonota                  Cliff Swallow  -1.800153
# 6                Progne subis                  Purple Martin   2.251470
# 7             Riparia riparia                   Bank Swallow   0.088349
# 8  Stelgidopteryx serripennis  Northern Rough-winged Swallow  -5.592324
# 9         Tachycineta bicolor                   Tree Swallow  -0.503988
#
#         p_value  r_squared  lower_conf_int  upper_conf_int
# 0  1.845393e-05   0.628034      -26.389402      -12.148307
# 1  2.723030e-05   0.558331       -4.653013       -2.026330
# 2  3.833710e-16   0.625401       -4.364329       -2.987475
# 3  1.892638e-06   0.491861       -5.422257       -2.585524
# 4  4.459768e-14   0.554012       -2.905064       -1.887517
# 5  2.030538e-07   0.486372       -2.383612       -1.216694
# 6  2.361924e-04   0.340116        1.140786        3.362153
# 7  9.488554e-01   0.000155       -2.711590        2.888288
# 8  8.103959e-13   0.559409       -6.841849       -4.342799
# 9  1.204566e-01   0.045740       -1.144573        0.136596

# %%
df_betas_sens_temp_sorted = df_betas_sens_temp.sort_values(by='slope')
print(df_betas_sens_temp_sorted.shape)

df_betas_sens_temp_sorted
# Out:
# (10, 7)
#               scientific_name                    common_name      slope  \
# 0    Antrostomus carolinensis             Chuck-will's-widow -19.268854
# 8  Stelgidopteryx serripennis  Northern Rough-winged Swallow  -5.592324
# 3            Chordeiles minor               Common Nighthawk  -4.003891
# 2           Chaetura pelagica                  Chimney Swift  -3.675902
# 1       Antrostomus vociferus         Eastern Whip-poor-will  -3.339671
# 4             Hirundo rustica                   Barn Swallow  -2.396291
# 5    Petrochelidon pyrrhonota                  Cliff Swallow  -1.800153
# 9         Tachycineta bicolor                   Tree Swallow  -0.503988
# 7             Riparia riparia                   Bank Swallow   0.088349
# 6                Progne subis                  Purple Martin   2.251470
#
#         p_value  r_squared  lower_conf_int  upper_conf_int
# 0  1.845393e-05   0.628034      -26.389402      -12.148307
# 8  8.103959e-13   0.559409       -6.841849       -4.342799
# 3  1.892638e-06   0.491861       -5.422257       -2.585524
# 2  3.833710e-16   0.625401       -4.364329       -2.987475
# 1  2.723030e-05   0.558331       -4.653013       -2.026330
# 4  4.459768e-14   0.554012       -2.905064       -1.887517
# 5  2.030538e-07   0.486372       -2.383612       -1.216694
# 9  1.204566e-01   0.045740       -1.144573        0.136596
# 7  9.488554e-01   0.000155       -2.711590        2.888288
# 6  2.361924e-04   0.340116        1.140786        3.362153

# %%
df_betas_sens_temp_sorted['rank'] = range(1, len(df_betas_sens_temp_sorted) + 1)
print(df_betas_sens_temp_sorted.shape)

df_betas_sens_temp_sorted
# Out:
# (10, 8)
#               scientific_name                    common_name      slope  \
# 0    Antrostomus carolinensis             Chuck-will's-widow -19.268854
# 8  Stelgidopteryx serripennis  Northern Rough-winged Swallow  -5.592324
# 3            Chordeiles minor               Common Nighthawk  -4.003891
# 2           Chaetura pelagica                  Chimney Swift  -3.675902
# 1       Antrostomus vociferus         Eastern Whip-poor-will  -3.339671
# 4             Hirundo rustica                   Barn Swallow  -2.396291
# 5    Petrochelidon pyrrhonota                  Cliff Swallow  -1.800153
# 9         Tachycineta bicolor                   Tree Swallow  -0.503988
# 7             Riparia riparia                   Bank Swallow   0.088349
# 6                Progne subis                  Purple Martin   2.251470
#
#         p_value  r_squared  lower_conf_int  upper_conf_int  rank
# 0  1.845393e-05   0.628034      -26.389402      -12.148307     1
# 8  8.103959e-13   0.559409       -6.841849       -4.342799     2
# 3  1.892638e-06   0.491861       -5.422257       -2.585524     3
# 2  3.833710e-16   0.625401       -4.364329       -2.987475     4
# 1  2.723030e-05   0.558331       -4.653013       -2.026330     5
# 4  4.459768e-14   0.554012       -2.905064       -1.887517     6
# 5  2.030538e-07   0.486372       -2.383612       -1.216694     7
# 9  1.204566e-01   0.045740       -1.144573        0.136596     8
# 7  9.488554e-01   0.000155       -2.711590        2.888288     9
# 6  2.361924e-04   0.340116        1.140786        3.362153    10

# %%
df_betas_sens_temp = df_betas_sens_temp.merge(df_betas_sens_temp_sorted[['scientific_name', 'rank']], on='scientific_name')
print(df_betas_sens_temp.shape)

df_betas_sens_temp
# Out:
# (10, 8)
#               scientific_name                    common_name      slope  \
# 0    Antrostomus carolinensis             Chuck-will's-widow -19.268854
# 1       Antrostomus vociferus         Eastern Whip-poor-will  -3.339671
# 2           Chaetura pelagica                  Chimney Swift  -3.675902
# 3            Chordeiles minor               Common Nighthawk  -4.003891
# 4             Hirundo rustica                   Barn Swallow  -2.396291
# 5    Petrochelidon pyrrhonota                  Cliff Swallow  -1.800153
# 6                Progne subis                  Purple Martin   2.251470
# 7             Riparia riparia                   Bank Swallow   0.088349
# 8  Stelgidopteryx serripennis  Northern Rough-winged Swallow  -5.592324
# 9         Tachycineta bicolor                   Tree Swallow  -0.503988
#
#         p_value  r_squared  lower_conf_int  upper_conf_int  rank
# 0  1.845393e-05   0.628034      -26.389402      -12.148307     1
# 1  2.723030e-05   0.558331       -4.653013       -2.026330     5
# 2  3.833710e-16   0.625401       -4.364329       -2.987475     4
# 3  1.892638e-06   0.491861       -5.422257       -2.585524     3
# 4  4.459768e-14   0.554012       -2.905064       -1.887517     6
# 5  2.030538e-07   0.486372       -2.383612       -1.216694     7
# 6  2.361924e-04   0.340116        1.140786        3.362153    10
# 7  9.488554e-01   0.000155       -2.711590        2.888288     9
# 8  8.103959e-13   0.559409       -6.841849       -4.342799     2
# 9  1.204566e-01   0.045740       -1.144573        0.136596     8

# %%
df_betas_sens_temp.sort_values(by='r_squared')
# Out:
#               scientific_name                    common_name      slope  \
# 7             Riparia riparia                   Bank Swallow   0.088349
# 9         Tachycineta bicolor                   Tree Swallow  -0.503988
# 6                Progne subis                  Purple Martin   2.251470
# 5    Petrochelidon pyrrhonota                  Cliff Swallow  -1.800153
# 3            Chordeiles minor               Common Nighthawk  -4.003891
# 4             Hirundo rustica                   Barn Swallow  -2.396291
# 1       Antrostomus vociferus         Eastern Whip-poor-will  -3.339671
# 8  Stelgidopteryx serripennis  Northern Rough-winged Swallow  -5.592324
# 2           Chaetura pelagica                  Chimney Swift  -3.675902
# 0    Antrostomus carolinensis             Chuck-will's-widow -19.268854
#
#         p_value  r_squared  lower_conf_int  upper_conf_int  rank
# 7  9.488554e-01   0.000155       -2.711590        2.888288     9
# 9  1.204566e-01   0.045740       -1.144573        0.136596     8
# 6  2.361924e-04   0.340116        1.140786        3.362153    10
# 5  2.030538e-07   0.486372       -2.383612       -1.216694     7
# 3  1.892638e-06   0.491861       -5.422257       -2.585524     3
# 4  4.459768e-14   0.554012       -2.905064       -1.887517     6
# 1  2.723030e-05   0.558331       -4.653013       -2.026330     5
# 8  8.103959e-13   0.559409       -6.841849       -4.342799     2
# 2  3.833710e-16   0.625401       -4.364329       -2.987475     4
# 0  1.845393e-05   0.628034      -26.389402      -12.148307     1

# %%
df_betas_sens_temp['species_code'] = ['CWWI', 'EWPW', 'CHSW', 'CONI', 'BARS', 'CLSW', 'PUMA', 'BANS', 'NRWS', 'TRES']
print(df_betas_sens_temp.shape)

df_betas_sens_temp
# Out:
# (10, 9)
#               scientific_name                    common_name      slope  \
# 0    Antrostomus carolinensis             Chuck-will's-widow -19.268854
# 1       Antrostomus vociferus         Eastern Whip-poor-will  -3.339671
# 2           Chaetura pelagica                  Chimney Swift  -3.675902
# 3            Chordeiles minor               Common Nighthawk  -4.003891
# 4             Hirundo rustica                   Barn Swallow  -2.396291
# 5    Petrochelidon pyrrhonota                  Cliff Swallow  -1.800153
# 6                Progne subis                  Purple Martin   2.251470
# 7             Riparia riparia                   Bank Swallow   0.088349
# 8  Stelgidopteryx serripennis  Northern Rough-winged Swallow  -5.592324
# 9         Tachycineta bicolor                   Tree Swallow  -0.503988
#
#         p_value  r_squared  lower_conf_int  upper_conf_int  rank species_code
# 0  1.845393e-05   0.628034      -26.389402      -12.148307     1         CWWI
# 1  2.723030e-05   0.558331       -4.653013       -2.026330     5         EWPW
# 2  3.833710e-16   0.625401       -4.364329       -2.987475     4         CHSW
# 3  1.892638e-06   0.491861       -5.422257       -2.585524     3         CONI
# 4  4.459768e-14   0.554012       -2.905064       -1.887517     6         BARS
# 5  2.030538e-07   0.486372       -2.383612       -1.216694     7         CLSW
# 6  2.361924e-04   0.340116        1.140786        3.362153    10         PUMA
# 7  9.488554e-01   0.000155       -2.711590        2.888288     9         BANS
# 8  8.103959e-13   0.559409       -6.841849       -4.342799     2         NRWS
# 9  1.204566e-01   0.045740       -1.144573        0.136596     8         TRES

# %%
df_betas_sens_temp['code_common_name'] = df_betas_sens_temp['species_code'] + ' (' + df_betas_sens_temp['common_name'] + ')' 
print(df_betas_sens_temp.shape)

df_betas_sens_temp
# Out:
# (10, 10)
#               scientific_name                    common_name      slope  \
# 0    Antrostomus carolinensis             Chuck-will's-widow -19.268854
# 1       Antrostomus vociferus         Eastern Whip-poor-will  -3.339671
# 2           Chaetura pelagica                  Chimney Swift  -3.675902
# 3            Chordeiles minor               Common Nighthawk  -4.003891
# 4             Hirundo rustica                   Barn Swallow  -2.396291
# 5    Petrochelidon pyrrhonota                  Cliff Swallow  -1.800153
# 6                Progne subis                  Purple Martin   2.251470
# 7             Riparia riparia                   Bank Swallow   0.088349
# 8  Stelgidopteryx serripennis  Northern Rough-winged Swallow  -5.592324
# 9         Tachycineta bicolor                   Tree Swallow  -0.503988
#
#         p_value  r_squared  lower_conf_int  upper_conf_int  rank species_code  \
# 0  1.845393e-05   0.628034      -26.389402      -12.148307     1         CWWI
# 1  2.723030e-05   0.558331       -4.653013       -2.026330     5         EWPW
# 2  3.833710e-16   0.625401       -4.364329       -2.987475     4         CHSW
# 3  1.892638e-06   0.491861       -5.422257       -2.585524     3         CONI
# 4  4.459768e-14   0.554012       -2.905064       -1.887517     6         BARS
# 5  2.030538e-07   0.486372       -2.383612       -1.216694     7         CLSW
# 6  2.361924e-04   0.340116        1.140786        3.362153    10         PUMA
# 7  9.488554e-01   0.000155       -2.711590        2.888288     9         BANS
# 8  8.103959e-13   0.559409       -6.841849       -4.342799     2         NRWS
# 9  1.204566e-01   0.045740       -1.144573        0.136596     8         TRES
#
#                        code_common_name
# 0             CWWI (Chuck-will's-widow)
# 1         EWPW (Eastern Whip-poor-will)
# 2                  CHSW (Chimney Swift)
# 3               CONI (Common Nighthawk)
# 4                   BARS (Barn Swallow)
# 5                  CLSW (Cliff Swallow)
# 6                  PUMA (Purple Martin)
# 7                   BANS (Bank Swallow)
# 8  NRWS (Northern Rough-winged Swallow)
# 9                   TRES (Tree Swallow)

# %%
# sns.set(rc={'figure.figsize':(8.3325*2, 5)})

predictor_variable = 'rank'

column_name = 'slope'

column_name_lower_conf_int = 'lower_conf_int'

column_name_upper_conf_int = 'upper_conf_int'

g = sns.lmplot(data=df_betas_sens_temp, x=predictor_variable, y=column_name, hue='code_common_name', fit_reg=False, 
                palette='colorblind', height=4.76, aspect=1.5)

g.set(xlabel=None)

g._legend.set_title('Code (Common name)')

plt.setp(g._legend.get_title(), fontsize=18)

# plt.setp(g._legend.get_texts(), fontsize=12)

sns.move_legend(g, 'center right', bbox_to_anchor=(1.2, 0.5), fontsize=16, alignment='left')

g.tick_params(bottom=False, labelbottom=False, labelsize=16)

# plt.tick_params(labelsize=16)

plt.axhline(y=0, color='0.8', linestyle='--')

right = df_betas_sens_temp[column_name_upper_conf_int] - df_betas_sens_temp[column_name]

plt.errorbar(x=df_betas_sens_temp[predictor_variable], y=df_betas_sens_temp[column_name], 
             yerr=[df_betas_sens_temp[column_name] - df_betas_sens_temp[column_name_lower_conf_int], right], 
             linestyle='', 
             ecolor=sns.color_palette('colorblind').as_hex())

for i, code in enumerate(df_betas_sens_temp['species_code']):
    plt.annotate(code, (df_betas_sens_temp['rank'].iloc[i], df_betas_sens_temp['upper_conf_int'].iloc[i]), 
                 ha='center', fontsize=12) #  + 0.4

# plt.ylabel('Change\nin\nsensitivity\nwith\ntemperature\nchange\nover\ntime', rotation=0, ha='right')

g.set(ylabel=None)

# plt.annotate('', xy=(-0.25, 0), xycoords='axes fraction', xytext=(-0.25, 1), 
#         arrowprops=dict(arrowstyle='<->', color=sns.color_palette('colorblind').as_hex()[3]))


# plt.annotate('', xy=(4, 0), xycoords='axes points', xytext=(4, 20), 
#         arrowprops=dict(arrowstyle='<->', color=sns.color_palette('colorblind').as_hex()[3]))

# ax.annotate('pixel offset from axes fraction',
#             xy=(1, 0), xycoords='axes fraction',
#             xytext=(-20, 20), textcoords='offset pixels',
#             horizontalalignment='right',
#             verticalalignment='bottom')


# plt.annotate('More sensitive in warmer places', xy=(-0.25, 0), xycoords='axes fraction', 
#              xytext=(-0.25, -0.1), 
#              ha='left', color=sns.color_palette('colorblind').as_hex()[3], fontsize=18)

# plt.annotate('Less sensitive in warmer places', xy=(-0.25, 1), xycoords='axes fraction', 
#              xytext=(-0.25, 1.1), ha='left', 
#              color=sns.color_palette('colorblind').as_hex()[3], fontsize=18)

print(g.figure.get_size_inches())

plt.savefig('/Users/alvastrand/Downloads/AOS_2023/Figures/sensitivity_temperature.pdf', bbox_inches='tight')
# Out:
# [10.4725  4.76  ]

# %%
plt.plot([0, 1], [1, 0])
plt.xticks([])
plt.yticks([])
plt.xlabel('Spring air temperature index (°C)', fontsize=15)
plt.ylabel('Mean arrival day (Julian day)', fontsize=15)
plt.text(0, -0.3, 'Lower', fontsize=15)
# , bbox=dict(boxstyle='square'))
plt.text(1, -0.3, 'Higher', horizontalalignment='right', fontsize=15)
# , bbox=dict(boxstyle='square'))
plt.text(-0.2, 0, 'Earlier', horizontalalignment='right', fontsize=15)
plt.text(-0.2, 1, 'Later', horizontalalignment='right', fontsize=15)
plt.show()

# %%
line = plt.plot([0, 1], [-1, 1])
line = line.pop(0)
line.remove()
plt.xticks([])
plt.yticks([])
plt.xlabel('Year', fontsize=20)
plt.ylabel('Spring air temperature index (°C)', fontsize=15)
plt.text(-0.3, 1, 'Higher', horizontalalignment='right', fontsize=15)
plt.text(-0.3, -1, 'Lower', horizontalalignment='right', fontsize=15)
plt.text(0, -1.3, 'Earlier', fontsize=15)
plt.text(1, -1.3, 'Later', horizontalalignment='right', fontsize=15)
plt.show()

# %%
line = plt.plot([0, 1], [-1, 1])
line = line.pop(0)
line.remove()
plt.xticks([])
plt.yticks([])
plt.xlabel('Air temperature change over time (°C/year)', fontsize=15)
plt.ylabel('Sensitivity (Julian day/°C)', fontsize=15)
plt.text(-0.3, 1, 'Lower', horizontalalignment='right', fontsize=15)
plt.text(-0.3, -1, 'Higher', horizontalalignment='right', fontsize=15)
plt.text(0, -1.5, 'Cooler', fontsize=15)
plt.text(1, -1.5, 'Warmer', horizontalalignment='right', fontsize=15)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))

line = plt.plot([0, 1], [-1, 1])
line = line.pop(0)
line.remove()

line.spines['right'].set_visible(False)

plt.xticks([])
plt.yticks([])
plt.xlabel('Functional trait', fontsize=18)
plt.ylabel('Sensitivity (Julian day/°C)', fontsize=18)
# plt.text(-0.3, 1, 'Lower', horizontalalignment='right', fontsize=15)
# plt.text(-0.3, -1, 'Higher', horizontalalignment='right', fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 7
#       4 line = line.pop(0)
#       5 line.remove()
# ----> 7 line.spines['right'].set_visible(False)
#       9 plt.xticks([])
#      10 plt.yticks([])
#
# AttributeError: 'Line2D' object has no attribute 'spines'
