# %%
import os

import pandas as pd

import statsmodels.formula.api as smf

from statsmodels.graphics.regressionplots import abline_plot

import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/Users/alvastrand/Documents/OU/Research/notebooks/Casey'

# %%
path = '/Users/alvastrand/Downloads/'

os.chdir(path)

# %%
os.getcwd()
# Out:
# '/Users/alvastrand/Downloads'

# %%
pd.set_option('max_columns', 100)

pd.set_option('max_rows', 100)

# %%
def my_function(species, model_type):

    path_to_file = species + '_both_' + model_type + '_ArrivalDate/'

    filename = 'data_arrival.csv'

    df = pd.read_csv(path_to_file + filename)

    print(len(df))
    
    #

    df = df[df['valid_GAM'] == True]

    print(len(df))

    # df['year']

    cells = sorted(list(df['cell'].unique()))

    cells_considered = []
    slopes = []
    intercepts = []
    r_squared = []
    p_values = []

    for cell in cells:

    #     print(cell)

        df_subset = df[df['cell'] == cell]

    #     print(len(df_subset))

        # df_subset.head(2)

        #

        if len(df_subset['year'].unique()) < 5: # or if len(df_subset) < 5

            continue

        model = smf.ols(formula='posterior_mean ~ year', data=df_subset)

        res = model.fit()

    #     ax = df_subset.plot(x='year', y='posterior_mean', kind='scatter')

    #     abline_plot(model_results=res, ax=ax)

    #     print(res.params[1])
    #     print(res.params[0])
    #     print(res.rsquared)
    #     print(res.pvalues[1])

        cells_considered.append(cell)
        slopes.append(res.params[1])
        intercepts.append(res.params[0])
        r_squared.append(res.rsquared)
        p_values.append(res.pvalues[1])

    df_ols = pd.DataFrame(data={'cell': cells_considered, 'slope': slopes, 'intercept': intercepts, 
                                'r_squared': r_squared, 'p_value': p_values})

    print(len(df_ols))

    df_ols['slope'].hist()
    
    plt.title('Distribution of the slopes of the OLS regressions of the ' + model_type + ' estimates over year')

    plt.show()
    
    # list_column_names = ['slope', 'intercept', 'r_squared', 'p_value']

    # df_ols_gam[list_column_names] = df_ols_gam[list_column_names].add_suffix('_GAM')

    # df_ols_iar[list_column_names] = df_ols_gam[list_column_names].add_suffix('_IAR')

    df_ols = df_ols.add_suffix('_' + model_type)

    df_ols = df_ols.rename(columns={'cell_' + model_type: 'cell'})

    return df, df_ols

# %%
list_species = ['BarnSwallow', 'CliffSwallow', 'NorthernRough-wingedSwallow', 'TreeSwallow']

for species in list_species:
    
    print(species)

    model_type = 'GAM'

    df_gam, df_ols_gam = my_function(species, model_type)

    model_type = 'IAR'

    df_iar, df_ols_iar = my_function(species, model_type)

    df_ols_merged = df_ols_gam.merge(df_ols_iar, on='cell')

    print(len(df_ols_merged))

    df_ols_merged.plot.scatter(x='slope_GAM', y='slope_IAR')
    
    plt.title('Correlation between the slopes of the OLS regressions of the IAR and GAM estimates over year')

    plt.show()
# Out:
# BarnSwallow
# 1376
# 529
# 49
# 1376
# 529
# 49
# 49
# CliffSwallow
# 1312
# 201
# 19
# 1312
# 201
# 19
# 19
# NorthernRough-wingedSwallow
# 912
# 430
# 41
# 912
# 430
# 41
# 41
# TreeSwallow
# 1424
# 483
# 41
# 1424
# 483
# 41
# 41

# %%
df_gam.head(2)
# Out:
#          species             sci_name  year  cell  cell_lat  cell_lng  mod  \
# 53  Tree Swallow  Tachycineta_bicolor  2002    58     44.43    -78.75  GAM
# 54  Tree Swallow  Tachycineta_bicolor  2002    59     43.78    -75.00  GAM
#
#     posterior_mean  posterior_sd  valid_GAM
# 53           97.71          7.76       True
# 54           95.14          7.06       True

# %%
df_ols_gam.head(2)
# Out:
#    cell  slope_GAM  intercept_GAM  r_squared_GAM  p_value_GAM
# 0    39  -0.440649     992.796753       0.051893     0.526750
# 1    40  -0.763676    1645.272649       0.225913     0.195988

# %%
df_iar.head(2)
# Out:
#          species             sci_name  year  cell  cell_lat  cell_lng  mod  \
# 53  Tree Swallow  Tachycineta_bicolor  2002    58     44.43    -78.75  IAR
# 54  Tree Swallow  Tachycineta_bicolor  2002    59     43.78    -75.00  IAR
#
#     posterior_mean  posterior_sd  valid_GAM
# 53           97.46          2.91       True
# 54           96.39          2.98       True

# %%
df_ols_iar.head(2)
# Out:
#    cell  slope_IAR  intercept_IAR  r_squared_IAR  p_value_IAR
# 0    39  -0.322641     754.945130       0.043976     0.560917
# 1    40  -0.399027     911.001946       0.092189     0.427027

# %%
df_ols_merged.head(2)
# Out:
#    cell  slope_GAM  intercept_GAM  r_squared_GAM  p_value_GAM  slope_IAR  \
# 0    39  -0.440649     992.796753       0.051893     0.526750  -0.322641
# 1    40  -0.763676    1645.272649       0.225913     0.195988  -0.399027
#
#    intercept_IAR  r_squared_IAR  p_value_IAR
# 0     754.945130       0.043976     0.560917
# 1     911.001946       0.092189     0.427027

# %%
df_ols_merged.sort_values(by='slope_IAR', ascending=False)
# Out:
#     cell  slope_GAM  intercept_GAM  r_squared_GAM  p_value_GAM  slope_IAR  \
# 3     43   2.251429   -4416.379524       0.362849     0.205731   1.258571
# 5     46   1.373689   -2655.079590       0.211109     0.299643   0.902131
# 9     50   1.841143   -3593.972286       0.180371     0.401250   0.638286
# 8     49   0.659000   -1222.889222       0.123903     0.352888   0.378667
# 36    79   0.132857    -188.757143       0.002523     0.924716   0.303143
# 6     47   0.691934   -1291.951916       0.230252     0.135263   0.187880
# 4     45   0.352363    -594.158956       0.081974     0.342949   0.171154
# 12    53   0.157091    -214.211455       0.027085     0.649586   0.103030
# 23    64   0.493324    -904.966132       0.147830     0.141450  -0.078618
# 17    58  -0.195319     494.111598       0.017338     0.639945  -0.091499
# 24    65  -0.170824     433.572382       0.025736     0.552844  -0.122147
# 14    55   0.010286      68.880381       0.000150     0.965455  -0.128500
# 15    56  -0.318311     735.842723       0.079756     0.349851  -0.171594
# 40    96  -0.489612    1104.041393       0.094988     0.457674  -0.198589
# 18    59  -0.132147     364.973265       0.037931     0.469798  -0.227382
# 39    95  -0.829119    1784.939927       0.348409     0.055911  -0.232234
# 4     45   0.352363    -594.158956       0.081974     0.342949   0.171154
# 6     47   0.691934   -1291.951916       0.230252     0.135263   0.187880
# 36    79   0.132857    -188.757143       0.002523     0.924716   0.303143
# 8     49   0.659000   -1222.889222       0.123903     0.352888   0.378667
# 9     50   1.841143   -3593.972286       0.180371     0.401250   0.638286
# 5     46   1.373689   -2655.079590       0.211109     0.299643   0.902131
# 3     43   2.251429   -4416.379524       0.362849     0.205731   1.258571
#
#     intercept_IAR  r_squared_IAR  p_value_IAR
# 26    5049.881000       0.961004     0.003307
# 21    1555.256364       0.322765     0.086640
# 20    1421.058235       0.273959     0.148144
# 28    1379.416709       0.525837     0.005035
# 31    1345.788319       0.309482     0.251618
# 33    1224.511868       0.236227     0.222036
# 32    1154.585000       0.415751     0.117924
# 30    1156.131476       0.485146     0.003914
# 35    1066.595895       0.560965     0.003216
# 37    1036.774658       0.531290     0.063113
# 29     954.817913       0.298606     0.043190
# 19     949.930786       0.346670     0.020930
# 1      911.001946       0.092189     0.427027
# 38     864.662685       0.176949     0.226087
# 7      854.179545       0.088002     0.349115
# 16     845.298182       0.103356     0.335018
# 25     839.519015       0.229347     0.060552
# 34     809.640879       0.314121     0.046334
# 2      825.503868       0.091463     0.620890
# 11     796.248696       0.193317     0.115690
# 0      754.945130       0.043976     0.560917
# 22     646.164618       0.164401     0.119209
# 27     634.279275       0.195803     0.200341
# 13     637.318571       0.036413     0.650799
# 10     597.619121       0.077087     0.358388
# 39     581.618103       0.065944     0.445901
# 18     556.692338       0.164549     0.119027
# 40     516.959612       0.079125     0.499740
# 15     440.465280       0.046834     0.477615
# 14     348.511000       0.028773     0.545600
# 24     336.569515       0.023619     0.569857
# 17     284.130174       0.016847     0.644764
# 23     246.844662       0.010651     0.703692
# 12    -105.360485       0.012203     0.761280
# 4     -228.771154       0.038532     0.520390
# 6     -277.051533       0.031211     0.603316
# 36    -530.258190       0.037243     0.714116
# 8     -658.020444       0.071590     0.486404
# 9    -1169.729905       0.080810     0.585079
# 5    -1704.627541       0.340219     0.169248
# 3    -2415.863810       0.347486     0.218199

# %%
len(df_iar[df_iar['cell'] == 68])
# Out:
# 5

# %%
df_iar[df_iar['cell'] == 68]
# Out:
#            species             sci_name  year  cell  cell_lat  cell_lng  mod  \
# 1042  Tree Swallow  Tachycineta_bicolor  2013    68     37.35    -92.21  IAR
# 1131  Tree Swallow  Tachycineta_bicolor  2014    68     37.35    -92.21  IAR
# 1220  Tree Swallow  Tachycineta_bicolor  2015    68     37.35    -92.21  IAR
# 1309  Tree Swallow  Tachycineta_bicolor  2016    68     37.35    -92.21  IAR
# 1398  Tree Swallow  Tachycineta_bicolor  2017    68     37.35    -92.21  IAR
#
#       posterior_mean  posterior_sd  valid_GAM
# 1042           83.02          3.35       True
# 1131           81.72          3.30       True
# 1220           80.06          3.19       True
# 1309           76.07          2.99       True
# 1398           73.51          2.76       True
